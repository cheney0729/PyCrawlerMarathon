# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
import json
r = requests.get('https://api.github.com/events')
#print(r.text)
print(json.loads(r.text))
# Out:
# [{'id': '12897491606', 'type': 'WatchEvent', 'actor': {'id': 12343667, 'login': 'Schinizer', 'display_login': 'Schinizer', 'gravatar_id': '', 'url': 'https://api.github.com/users/Schinizer', 'avatar_url': 'https://avatars.githubusercontent.com/u/12343667?'}, 'repo': {'id': 135329998, 'name': 'Tinder/Scarlet', 'url': 'https://api.github.com/repos/Tinder/Scarlet'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2020-07-14T08:28:45Z', 'org': {'id': 10427184, 'login': 'Tinder', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/Tinder', 'avatar_url': 'https://avatars.githubusercontent.com/u/10427184?'}}, {'id': '12897491527', 'type': 'PushEvent', 'actor': {'id': 843617, 'login': 'lindig', 'display_login': 'lindig', 'gravatar_id': '', 'url': 'https://api.github.com/users/lindig', 'avatar_url': 'https://avatars.githubusercontent.com/u/843617?'}, 'repo': {'id': 58365569, 'name': 'lindig/xenopsd', 'url': 'https://api.github.com/repos/lindig/xenopsd'}, 'payload': {'push_id': 5370463025, 'size': 2, 'distinct_size': 2, 'ref': 'refs/heads/polly', 'head': '0610645270ff232124cab8c92eeb180300ac6312', 'before': '6aa338a12324bb1989137a38d14ec7af23bfa351', 'commits': [{'sha': '46d396ad8539597b5c724d6ad47b0ae8639ff54d', 'author': {'email': 'christian.lindig@citrix.com', 'name': 'Christian Lindig'}, 'message': 'Vendor Polly - light-weight epoll(2) bindings\n\nPolly from github.com/lindig/polly is a light-weight binding for the\nepoll(2) system call. We vendor it here to facilitate a quick turnaround\nfor fixes because it has not yet been used anywhere else.\n\nSigned-off-by: Christian Lindig <christian.lindig@citrix.com>', 'distinct': True, 'url': 'https://api.github.com/repos/lindig/xenopsd/commits/46d396ad8539597b5c724d6ad47b0ae8639ff54d'}, {'sha': '0610645270ff232124cab8c92eeb180300ac6312', 'author': {'email': 'christian.lindig@citrix.com', 'name': 'Christian Lindig'}, 'message': 'Replace Core.Epoll with Polly for epoll bindings\n\nWe are using epoll() for QMP communications. The existing implementation\nas part of the JaneStreet Core libraries brings along a massive code\nbase. This commit removes that dependency and brings in a minimal\nbinding for epoll called Polly. For now, until is proven to be good, it\nis vendored under vendor/polly but it could be moved to xs-opam longer\nterm.\n\nSigned-off-by: Christian Lindig <christian.lindig@citrix.com>', 'distinct': True, 'url': 'https://api.github.com/repos/lindig/xenopsd/commits/0610645270ff232124cab8c92eeb180300ac6312'}]}, 'public': True, 'created_at': '2020-07-14T08:28:45Z'}, {'id': '12897491567', 'type': 'PushEvent', 'actor': {'id': 58833107, 'login': 'ypqghs363', 'display_login': 'ypqghs363', 'gravatar_id': '', 'url': 'https://api.github.com/users/ypqghs363', 'avatar_url': 'https://avatars.githubusercontent.com/u/58833107?'}, 'repo': {'id': 227725053, 'name': 'ypqghs363/ntdtv', 'url': 'https://api.github.com/repos/ypqghs363/ntdtv'}, 'payload': {'push_id': 5370463066, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '41aedc990e821870467fa0fe1a209e419c7b30fb', 'before': 'ecf69de905ce50492feb9b9d0110c9c8bad6385e', 'commits': [{'sha': '41aedc990e821870467fa0fe1a209e419c7b30fb', 'author': {'email': '58833107+ypqghs363@users.noreply.github.com', 'name': 'ypqghs363'}, 'message': 'Update culture-world_3.md', 'distinct': True, 'url': 'https://api.github.com/repos/ypqghs363/ntdtv/commits/41aedc990e821870467fa0fe1a209e419c7b30fb'}]}, 'public': True, 'created_at': '2020-07-14T08:28:45Z'}, {'id': '12897491577', 'type': 'CreateEvent', 'actor': {'id': 31379392, 'login': 'namziji', 'display_login': 'namziji', 'gravatar_id': '', 'url': 'https://api.github.com/users/namziji', 'avatar_url': 'https://avatars.githubusercontent.com/u/31379392?'}, 'repo': {'id': 219123756, 'name': 'THRAGOO/Morningbees-server', 'url': 'https://api.github.com/repos/THRAGOO/Morningbees-server'}, 'payload': {'ref': 'feature/bee_info', 'ref_type': 'branch', 'master_branch': 'develop', 'descript ...

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
url='https://cat-fact.herokuapp.com/facts'

r=requests.get(url)    
response=r.text
print(response)
# Out:
# {"all":[{"_id":"58e008b80aac31001185ed0d","text":"Adult cats only meow to communicate with humans.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":13,"userUpvoted":null},{"_id":"5887e1d85c873e0011036889","text":"Cats make about 100 different sounds. Dogs make only about 10.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":11,"userUpvoted":null},{"_id":"58e009420aac31001185ed11","text":"Basically all cartoon cats lied to us: Raw fish is off the table for cats as well.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":11,"userUpvoted":null},{"_id":"5b4910ae0508220014ccfe90","text":"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":11,"userUpvoted":null},{"_id":"58f8d7b98098c80011c50a42","text":"A man named Ernest Misko gave marijuana tinctures to his 24-year-old cat, Borzo. In a couple of days, he was walking normally again, pain-free. Veterinarians in many states are still not legally allowed to prescribe cannabis to cats, even in states that have legalized medicinal marijuana for humans.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":10,"userUpvoted":null},{"_id":"58e00b970aac31001185edf9","text":"A house cat is faster than Usain Bolt.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":10,"userUpvoted":null},{"_id":"58e00b450aac31001185ed21","text":"There are 45 Hemingway cats living at the author's former home in Key West, Fla.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":9,"userUpvoted":null},{"_id":"5b4911940508220014ccfe94","text":"By the time a cat is 9 years old, it will only have been awake for three years of its life.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":9,"userUpvoted":null},{"_id":"58e00af60aac31001185ed1d","text":"It was illegal to slay cats in ancient Egypt, in large part because they provided the great service of controlling the rat population.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":8,"userUpvoted":null},{"_id":"5e236d6bdc76630015d4c51f","type":"cat","text":"gato loves grace","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":8,"userUpvoted":null},{"_id":"5b4912c60508220014ccfe99","text":"Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":8,"userUpvoted":null},{"_id":"58e009650aac31001185ed13","text":"In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":7,"userUpvoted":null},{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":7,"userUpvoted":null},{"_id":"59a60b8e6acf530020f3586e","text":"Cat owners are 17% more likely to have a graduate degree than non cat owners.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":7,"userUpvoted":null},{"_id":"5b199196ce456e00142 ...
